# %%
import pandas as pd
data=pd.read_csv("hire_data_NaN_value.csv")
data
# Out:
#      Percentage  Backlog  Internship  First_Round  Communication_Skills  \
# 0         81.00      0.0         1.0        75.00                 80.00
# 1         70.00      0.0         3.0        87.00                 70.00
# 2         81.00      2.0         3.0        75.00                 67.00
# 3         56.00      3.0         3.0        42.00                 76.00
# 4         74.00      4.0         3.0        82.00                 75.00
# 5         69.00      0.0         2.0        74.00                 71.00
# 6         46.00      3.0         1.0        67.00                 86.00
# 7         70.00      0.0         1.0        78.00                 75.00
# 8         85.00      1.0         1.0        65.00                 72.00
# 9         70.00      1.0         1.0        80.00                 85.00
# 10        90.00      NaN         1.0          NaN                   NaN
# 11        70.00      0.0         1.0        84.00                 75.00
# ...

# %%
data.dropna()#basically deletes all rows having even 1 null entry
# Out:
#      Percentage  Backlog  Internship  First_Round  Communication_Skills  \
# 0         81.00      0.0         1.0        75.00                 80.00
# 1         70.00      0.0         3.0        87.00                 70.00
# 2         81.00      2.0         3.0        75.00                 67.00
# 3         56.00      3.0         3.0        42.00                 76.00
# 4         74.00      4.0         3.0        82.00                 75.00
# 5         69.00      0.0         2.0        74.00                 71.00
# 6         46.00      3.0         1.0        67.00                 86.00
# 7         70.00      0.0         1.0        78.00                 75.00
# 8         85.00      1.0         1.0        65.00                 72.00
# 9         70.00      1.0         1.0        80.00                 85.00
# 11        70.00      0.0         1.0        84.00                 75.00
# 12        69.00      0.0         1.0        66.00                 71.00
# ...

# %%
data.dropna(how='any')#basically deletes all rows having even 1 null entry
# Out:
#      Percentage  Backlog  Internship  First_Round  Communication_Skills  \
# 0         81.00      0.0         1.0        75.00                 80.00
# 1         70.00      0.0         3.0        87.00                 70.00
# 2         81.00      2.0         3.0        75.00                 67.00
# 3         56.00      3.0         3.0        42.00                 76.00
# 4         74.00      4.0         3.0        82.00                 75.00
# 5         69.00      0.0         2.0        74.00                 71.00
# 6         46.00      3.0         1.0        67.00                 86.00
# 7         70.00      0.0         1.0        78.00                 75.00
# 8         85.00      1.0         1.0        65.00                 72.00
# 9         70.00      1.0         1.0        80.00                 85.00
# 11        70.00      0.0         1.0        84.00                 75.00
# 12        69.00      0.0         1.0        66.00                 71.00
# ...

# %%
data.dropna(how='all')#basically deletes only those rows where all the entries are null entries
# Out:
#      Percentage  Backlog  Internship  First_Round  Communication_Skills  \
# 0         81.00      0.0         1.0        75.00                 80.00
# 1         70.00      0.0         3.0        87.00                 70.00
# 2         81.00      2.0         3.0        75.00                 67.00
# 3         56.00      3.0         3.0        42.00                 76.00
# 4         74.00      4.0         3.0        82.00                 75.00
# 5         69.00      0.0         2.0        74.00                 71.00
# 6         46.00      3.0         1.0        67.00                 86.00
# 7         70.00      0.0         1.0        78.00                 75.00
# 8         85.00      1.0         1.0        65.00                 72.00
# 9         70.00      1.0         1.0        80.00                 85.00
# 10        90.00      NaN         1.0          NaN                   NaN
# 11        70.00      0.0         1.0        84.00                 75.00
# ...
