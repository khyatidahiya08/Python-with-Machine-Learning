# %%
import pandas as pd
df=pd.read_csv('hire_data1.csv')
df.head(12)
# Out:
#     Percentage  Backlog  Internship  First_Round  Communication_Skills  Hired  \
# 0         81.0        0           1         75.0                  80.0      1
# 1         70.0        0           3         87.0                  70.0      1
# 2         81.0        2           3         75.0                  67.0      0
# 3         56.0        3           3         42.0                  76.0      0
# 4         74.0        4           3         82.0                  75.0      1
# 5         69.0        0           2         74.0                  71.0      1
# 6         46.0        3           1         67.0                  86.0      0
# 7         70.0        0           1         78.0                  75.0      1
# 8         85.0        1           1         65.0                  72.0      1
# 9         70.0        1           1         80.0                  85.0      1
# 10        90.0        0           1         88.0                  89.0      1
# ...

# %%
len(df)#shows the number of entries in df
# Out:
# 377

# %%
df.drop_duplicates(subset=['Percentage'],keep='first')#deletes all the dupliacte values and keeps only the first value
# Out:
#      Percentage  Backlog  Internship  First_Round  Communication_Skills  \
# 0         81.00        0           1        75.00                 80.00
# 1         70.00        0           3        87.00                 70.00
# 3         56.00        3           3        42.00                 76.00
# 4         74.00        4           3        82.00                 75.00
# 5         69.00        0           2        74.00                 71.00
# 6         46.00        3           1        67.00                 86.00
# 8         85.00        1           1        65.00                 72.00
# 10        90.00        0           1        88.00                 89.00
# 15        67.00        1           1        64.00                 75.00
# 16        80.00        0           1        68.00                 77.00
# 18        89.00        0           1        78.00                 80.00
# 20        87.00        0           1        88.00                 85.00
# ...

# %%
len(df.drop_duplicates(subset=['Percentage'],keep='first'))
# Out:
# 78

# %%
df.drop_duplicates(subset=['Percentage','First_Round'])#this basically concatenates the two columns i.e
#percentage and first round and then drops the duplicate values i.e if percentage and first round in index 1 is 81 and 75
#percentage and first round in index 2  is 81 and 75
#then the row is deleted
# Out:
#      Percentage  Backlog  Internship  First_Round  Communication_Skills  \
# 0         81.00        0           1        75.00                 80.00
# 1         70.00        0           3        87.00                 70.00
# 3         56.00        3           3        42.00                 76.00
# 4         74.00        4           3        82.00                 75.00
# 5         69.00        0           2        74.00                 71.00
# 6         46.00        3           1        67.00                 86.00
# 7         70.00        0           1        78.00                 75.00
# 8         85.00        1           1        65.00                 72.00
# 9         70.00        1           1        80.00                 85.00
# 10        90.00        0           1        88.00                 89.00
# 11        70.00        0           1        84.00                 75.00
# 12        69.00        0           1        66.00                 71.00
# ...

# %%
len(df.drop_duplicates(subset=['Percentage','First_Round']))
# Out:
# 301
