# %%
import pandas as pd
data=pd.read_csv("hire.csv")
data
# Out:
#      Percentage  Backlog  Internship  First_Round  Communication_Skills  \
# 0         81.00        0           1        75.00                 80.00
# 1         70.00        0           3        87.00                 70.00
# 2         81.00        2           3        75.00                 67.00
# 3         56.00        3           3        42.00                 76.00
# 4         74.00        4           3        82.00                 75.00
# 5         69.00        0           2        74.00                 71.00
# 6         46.00        3           1        67.00                 86.00
# 7         70.00        0           1        78.00                 75.00
# 8         85.00        1           1        65.00                 72.00
# 9         70.00        1           1        80.00                 85.00
# 10        90.00        0           1        88.00                 89.00
# 11        70.00        0           1        84.00                 75.00
# ...

# %%
import pandas as pd
data=pd.read_csv("hire.csv",squeeze=True,usecols=["Percentage"])#shows indices of values in the column without the column name 
#however this command works only for 1 column i.e squeeze has to be used before data[9]
data[9]#this extracts the value at index 9
# Out:
# 70.0

# %%
data[-50:]#shows values from index -50 to the last index
# Out:
#      Percentage  Backlog  Internship  First_Round  Communication_Skills  \
# 327       65.00        1           1        65.00                 70.00
# 328       65.00        3           3        85.00                 80.00
# 329       60.00        5           1        40.00                 70.00
# 330       90.00        0           0        70.00                 60.00
# 331       30.00        8           0        20.00                 35.00
# 332       69.00        2           3        85.00                 95.00
# 333       59.00        3           2        80.00                 80.00
# 334       41.00        4           5        85.00                 62.00
# 335       64.00        2           4        80.00                 80.00
# 336       55.00        3           3        87.00                 89.00
# 337       66.00        4           2        80.00                 80.00
# 338       75.00        8           6        80.00                 80.00
# ...

# %%
data[50:100]#shows values from index 50 to 100
# Out:
#     Percentage  Backlog  Internship  First_Round  Communication_Skills  Hired  \
# 50        87.0        1           3         70.0                  78.0      1
# 51        99.0        0           5         90.0                  89.0      1
# 52        92.0        0           4         89.0                  78.0      1
# 53        67.0        4           7         92.0                  75.0      1
# 54        80.0        2           4         80.0                  80.0      1
# 55        98.0        1           4         80.0                  89.0      1
# 56        76.0        0           7         90.0                  80.0      1
# 57        87.0        0           6         80.0                  10.0      0
# 58        56.0        5           0         54.0                  40.0      0
# 59        64.0        0           0         56.0                  55.0      0
# 60        67.0        4           6         60.0                  55.0      0
# ...

# %%
data[-30:-10]#shows values from index -30 to -10
# Out:
#      Percentage  Backlog  Internship  First_Round  Communication_Skills  \
# 347       71.00        4           4         81.0                  71.0
# 348       64.00        1          69          0.0                  64.0
# 349       60.00        3          65          0.0                  61.0
# 350       60.00        6           0         60.0                  60.0
# 351       61.00        6           0         60.0                  60.0
# 352       62.00        5           0         62.0                  63.0
# 353       63.00        4           0         63.0                  65.0
# 354       64.00        3           0         65.0                  69.0
# 355       64.00        5           2         79.0                  69.0
# 356       63.00        6           2         78.0                  68.0
# 357       62.00        7           1         77.0                  67.0
# 358       61.00        8           1         76.0                  66.0
# ...
